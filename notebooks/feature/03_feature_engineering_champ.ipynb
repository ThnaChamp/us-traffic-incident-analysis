# %%
# Import library here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train_clean = pd.read_csv("../../data/processed/01.3/accidents_advance_clean.csv")

df_train_clean.head(10)
# Out:
#    Severity           Start_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 0         3  2016-11-08 08:50:37  29.718655  -95.321053      0.009950
# 1         2  2021-07-26 07:04:56  38.927551 -121.080093      0.000000
# 2         2  2018-10-24 08:23:38  34.776241  -86.672829      0.000000
# 3         3  2019-07-11 10:42:48  42.384880  -83.149467      0.470004
# 4         2  2020-11-06 01:29:00  33.776575 -117.837134      0.387980
# 5         2  2021-07-02 15:22:00  36.989497 -121.935657      0.033435
# 6         2  2019-08-09 08:44:18  30.419380  -91.096611      0.000000
# 7         2  2021-12-10 07:02:30  33.194519 -111.901301      1.015955
# 8         3  2021-04-26 19:57:38  29.384928  -98.512321      0.000000
# 9         2  2017-04-18 19:05:08  26.589575  -81.703766      0.000000
#
#                                          Description                 Street  \
# 0  Accident on I-45 Northbound at I-45 Exits 43A ...                 I-45 N
# 1  Right hand shoulder blocked due to accident on...              Taylor Ln
# 2  Lane blocked due to accident on AL-255 Researc...            Highway 255
# 3  Entry ramp to I-96 Westbound from Davison West...  Edward J Jeffries Fwy
# 4  1023: NB 55 JNO 22. SV REAR ENDED VV AND WAS L...       Garden Grove Fwy
# 5  Incident on PARK AVE WB near SOQUEL DR Expect ...             Park Ave N
# 6  Accident on LA-73 Jefferson Hwy at LA-3064 Ess...               Essen Ln
# 7  Stationary traffic on I-10 E - Pearl Harbor Me...                 I-10 E
# 8  Three lanes blocked due to accident on I-35 So...                 I-35 N
# 9                 Accident on 25th St at Curtis Ave.             25th St SW
#
#            City            County State  ... Turning_Loop Sunrise_Sunset  \
# 0       Houston            Harris    TX  ...        False            Day
# 1        Auburn            Placer    CA  ...        False            Day
# 2    Huntsville           Madison    AL  ...        False            Day
# 3       Detroit             Wayne    MI  ...        False            Day
# 4        Orange            Orange    CA  ...        False          Night
# 5        Soquel        Santa Cruz    CA  ...        False            Day
# 6   Baton Rouge  East Baton Rouge    LA  ...        False            Day
# 7      Maricopa             Pinal    AZ  ...        False          Night
# 8   San Antonio             Bexar    TX  ...        False            Day
# 9  Lehigh Acres               Lee    FL  ...        False            Day
#
#    Civil_Twilight  Nautical_Twilight  Astronomical_Twilight  Duration(min)  \
# 0             Day                Day                    Day       3.405079
# 1             Day                Day                    Day       3.862833
# 2             Day                Day                    Day       3.422633
# 3             Day                Day                    Day       4.784571
# 4           Night              Night                  Night       4.952535
# 5             Day                Day                    Day       5.758376
# 6             Day                Day                    Day       4.665638
# 7             Day                Day                    Day       4.248495
# 8             Day                Day                    Day       5.332880
# 9             Day                Day                    Day       3.751463
#
#    Start_Date Hour  Month  Weather_Group
# 0  2016-11-08    8     11         Cloudy
# 1  2021-07-26    7      7          Clear
# 2  2018-10-24    8     10          Clear
# 3  2019-07-11   10      7          Clear
# 4  2020-11-06    1     11          Clear
# 5  2021-07-02   15      7         Cloudy
# 6  2019-08-09    8      8         Cloudy
# 7  2021-12-10    7     12          Clear
# 8  2021-04-26   19      4          Clear
# 9  2017-04-18   19      4         Cloudy
#
# [10 rows x 42 columns]

# %%
df_train_clean["City"].value_counts()
# Out:
# City
# Houston              126099
# Miami                124523
# Los Angeles          113281
# Charlotte            104172
# Dallas                96351
#                       ...
# Mound Bayou               1
# Bradford township         1
# Summitville               1
# Grand Rapids city         1
# Hobbsville                1
# Name: count, Length: 12128, dtype: int64
